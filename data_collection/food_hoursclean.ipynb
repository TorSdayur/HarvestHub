# %%
import pandas as pd 

df = pd.read_csv('csv/food_rows.csv')

# %%
df['HOURS']
# Out:
# 0               4-6PM
# 1               2-5PM
# 2      11:30AM-2:30PM
# 3              8-10AM
# 4            4:30-5PM
#             ...
# 552             3-5PM
# 553         9:30-11AM
# 554      8:30-10:30AM
# 555    2-4PM/10AM-4PM
# 556          10AM-1PM
# Name: HOURS, Length: 557, dtype: object

# %%
pd.set_option('display.max_rows', 200)
hours = df['HOURS']
hours.head(200)
# Out:
# 0                                 4-6PM
# 1                                 2-5PM
# 2                        11:30AM-2:30PM
# 3                                8-10AM
# 4                              4:30-5PM
# 5                           3:30-4:30PM
# 6                          11AM-12:45PM
# 7                              11AM-3PM
# 8                          12:30-3:30PM
# 9                              9AM-12PM
# 10                     10AM-1PM & 5-6PM
# 11                             11AM-1PM
# 12                             10AM-1PM
# 13                               12-1PM
# 14                               8-10AM
# 15                            10AM-12PM
# 16                           10-11:30AM
# 17                               9-11AM
# 18                            9-10:30AM
# 19              9-10:30AM & 11:30AM-1PM
# 20                                5-6PM
# 21                            9:30-11AM
# 22                             1:30-3PM
# 23                         10:30AM-12PM
# 24                             9AM-12PM
# 25                             1:30-5PM
# 26                            9-10:30AM
# 27                            12:30-2PM
# 28                             2-3:30PM
# 29                              10-11AM
# 30                         12-2PM/4-6PM
# 31                            10AM-12PM
# 32                 9:30AM-12PM&1:30-3PM
# 33                            9-11:30AM
# 34                               9-11AM
# 35                           10AM - 1PM
# 36                            10AM-12PM
# 37                            12:30-2PM
# 38                            10AM-12PM
# 39                              9AM-2PM
# 40                             3:15-5PM
# 41                            10AM-12PM
# 42                             11AM-1PM
# 43                               8-11AM
# 44                                1-4PM
# 45                             9AM-12PM
# 46                       9AM-12PM&1-4PM
# 47                                4-6PM
# 48                             4:30-6PM
# 49                                2-5PM
# 50                             8:30-9AM
# 51                             9AM-12PM
# 52                             11AM-2PM
# 53                            10AM-12PM
# 54                        10:30-11:30AM
# 55                      10:30AM-12:30PM
# 56                             10AM-1PM
# 57                 9-11:30AM & 1-2:30PM
# 58                               9-11AM
# 59                    10-11AM/10AM-12PM
# 60                               8-11AM
# 61                               12-2PM
# 62                            10AM-12PM
# 63                              9AM-1PM
# 64                         9:30-11:30AM
# 65                              9AM-3PM
# 66          4:30-5:30PM/11:30AM-12:30PM
# 67                             10AM-1PM
# 68                        7:30AM-8:45AM
# 69                             9AM-12PM
# 70                            9-11:30AM
# 71                            12:45-3PM
# 72              6:45-7:15PM/3:45-4:15PM
# 73                             11AM-1PM
# 74                            10AM-12PM
# 75                         9:30-10:30AM
# 76                            8-:8:30AM
# 77                      11:15AM-12:15PM
# 78                             10AM-3PM
# 79                         12:30-1:30PM
# 80                            11AM-12PM
# 81                      9-10AM&1-2:30PM
# 82                            10AM-12PM
# 83                              9AM-1PM
# 84                              9AM-2PM
# 85                          10AM-2:30PM
# 86                          2:30-3:30PM
# 87                       3-5PM/11AM-2PM
# 88                               12-2PM
# 89                               9-11AM
# 90                            10AM-12PM
# 91                          11:30AM-1PM
# 92                              9AM-4PM
# 93                      9:30AM - 1:30PM
# 94                   8:30-9:30AM/ 6-7PM
# 95                               8-11AM
# 96                            10AM-12PM
# 97                          8:30-9:30AM
# 98                          5:30-6:30PM
# 99                  9A-2P/11A-2P/9A-12P
# 100                        10:30AM-12PM
# 101                            11AM-2PM
# 102                            10AM-2PM
# 103                            10AM-1PM
# 104                            12PM-1PM
# 105                      1-3PM/1-3:30PM
# 106                            9AM-12PM
# 107                           9-10:30AM
# 108                           11AM-12PM
# 109                              9-11AM
# 110                       11:30AM - 1PM
# 111                           12-1:30PM
# 112                         11:30AM-1PM
# 113                     10:30AM-12:30PM
# 114                     10:30AM-12:30PM
# 115                               1-2PM
# 116                     10:30AM-12:30PM
# 117                           10AM-12PM
# 118                              9-11AM
# 119                        8:30-10:30AM
# 120                              12-6PM
# 121                             9AM-1PM
# 122                               4-6PM
# 123                              12-3PM
# 124                            1:30-4PM
# 125                       9:30AM-1:30PM
# 126                           12:30-2PM
# 127                           9-11:30AM
# 128                      11AM-1PM/3-6PM
# 129                              12-2PM
# 130                12-1PM & 4:30-5:30PM
# 131                           9:30-11AM
# 132                              12-1PM
# 133                        9:30-11:30AM
# 134                          11-11:30AM
# 135                         11:30AM-1PM
# 136                               2-4PM
# 137                           10AM-12PM
# 138                           9:30-11AM
# 139                              12-1PM
# 140               10-11:30A&12:30-1:30P
# 141                        9:30-11:30AM
# 142                              12-1PM
# 143                         10:30AM-1PM
# 144                            11AM-2PM
# 145                               5-6PM
# 146                              12-2PM
# 147                       9:30AM-1:30PM
# 148                            2:30-4PM
# 149                           9-10:30AM
# 150                              12-2PM
# 151                              12-2PM
# 152                            11AM-3PM
# 153                   12-2PM/11AM - 1PM
# 154                        3-4PM/12-1PM
# 155                              12-1PM
# 156                            11AM-1PM
# 157                        7:30-10:30AM
# 158                           12-1:30PM
# 159                         5:30-6:30PM
# 160                           5:30-10PM
# 161                    10AM-12PM/9-11AM
# 162                 12:30-2:30PM/ 5-7PM
# 163                            10AM-1PM
# 164                           12:30-2PM
# 165                      11:30AM-1:30PM
# 166                     2-6PM/8-11:30AM
# 167                             7AM-1PM
# 168                            10AM-2PM
# 169                              12-1PM
# 170                           10AM-12PM
# 171                              12-2PM
# 172                               2-4PM
# 173                     10:30AM-12:45PM
# 174                             9AM-1PM
# 175                           9-10:30AM
# 176                             9AM-5PM
# 177                            11AM-1PM
# 178                         7:30-9:30AM
# 179                        11AM-12:30PM
# 180               11:30AM-3:30PM/12-3PM
# 181                              9-11AM
# 182                           9AM - 1PM
# 183                             8AM-1PM
# 184                         7:30-9:30AM
# 185                              9-11AM
# 186                            9AM-12PM
# 187                            10AM-1PM
# 188                           12:30-2PM
# 189                             10-11AM
# 190                            10AM-4PM
# 191                        9:30-10:30AM
# 192    9A-2P&3:30-6:30P/9A-2P/10A-1:30P
# 193                        10AM-12:30PM
# 194                          10-11:30AM
# 195                            2-4:50PM
# 196                           12-1:30PM
# 197                               2-5PM
# 198                            11AM-1PM
# 199                         9:30AM-12PM
# Name: HOURS, dtype: object

# %%
import pandas as pd
import re

# Function to standardize time and convert to 24-hour format
def convert_to_24h(time_str):
    time_str = re.sub(r'\s+', '', time_str)  # Remove spaces
    time_str = time_str.upper()

    # Handle cases like 4-6PM by adding the PM to the end time
    match = re.match(r'(\d{1,2}):?(\d{0,2})?-?(\d{1,2}):?(\d{0,2})?(AM|PM)', time_str)
    if match:
        start_hour = match.group(1)
        start_minute = match.group(2) if match.group(2) else '00'
        end_hour = match.group(3)
        end_minute = match.group(4) if match.group(4) else '00'
        period = match.group(5)

        # Convert start time
        start_hour = int(start_hour)
        if period == 'PM' and start_hour != 12:
            start_hour += 12
        elif period == 'AM' and start_hour == 12:
            start_hour = 0
        start_time = f'{start_hour:02}:{start_minute}'

        # Convert end time, assume same period unless explicitly stated
        end_hour = int(end_hour)
        if period == 'PM' and end_hour != 12:
            end_hour += 12
        elif period == 'AM' and end_hour == 12:
            end_hour = 0
        end_time = f'{end_hour:02}:{end_minute}'

        return f'{start_time} - {end_time}'

    # For cases like 10AM-1PM where the period changes
    time_format = re.findall(r'(\d{1,2}:\d{2}|\d{1,2})(A|P)M', time_str)

    def to_24h(time, period):
        if ':' not in time:
            time += ':00'
        hour, minute = map(int, time.split(':'))
        if period == 'P' and hour != 12:
            hour += 12
        elif period == 'A' and hour == 12:
            hour = 0
        return f'{hour:02}:{minute:02}'

    return ' - '.join([to_24h(time, period) for time, period in time_format])

# Split by '/' and '&', then convert each time range
df['Time_Ranges'] = df['HOURS'].str.split(r'[/&]').apply(lambda times: [convert_to_24h(t) for t in times])

# Expand the list into separate rows
df_expanded = df.explode('Time_Ranges').reset_index(drop=True)

# Further split into Start and End times
df_expanded[['Start_Time', 'End_Time']] = df_expanded['Time_Ranges'].str.split(' - ', expand=True)

# Handle cases where there's no End_Time (single time entries)
df_expanded['End_Time'] = df_expanded['End_Time'].fillna(df_expanded['Start_Time'])

print(df_expanded)
# Out:
#         ID TYPE                                    PROGRAM       ORG PHONE  \
# 0    80015   FP                 THE BIBLE CHURCH OF CHRIST    718-293-1928
# 1    80026   FP         BRONX SEVENTH DAY ADVENTIST CHURCH    646-353-8926
# 2    80029   FP  BRONX TEMPLE SEVENTH DAY ADVENTIST CHURCH    718-842-4504
# 3    80065   FP                  GETHSEMANE BAPTIST CHURCH    347-948-0772
# 4    80081   FP                HOLY TABERNACLE CHURCH INC.  (718) 293-9862
# ..     ...  ...                                        ...             ...
# 623  87208   FP                  ISAACS HOLMES FOOD PANTRY    212-360-7620
# 624  87233   FP                FOREST HILLS SENIORS CENTER    929-349-9740
# 625  87341   FP                 CHURCH OF GOD OF SALVATION    718-693-6486
# 626  87341   FP                 CHURCH OF GOD OF SALVATION    718-693-6486
# 627  87357   FP                     ST. EDWARD FOOD PANTRY  (718) 984-1625
#
#           DAYS           HOURS  LONGITUDE   LATITUDE  \
# 0    SUN (2,4)           4-6PM -73.968168  40.693683
# 1         THUR           2-5PM -73.955831  40.654492
# 2     M,W,THUR  11:30AM-2:30PM -73.912934  40.668113
# 3         THUR          8-10AM -73.963443  40.576623
# 4          TUE        4:30-5PM -73.912934  40.668113
# ..         ...             ...        ...        ...
# 623        WED       9:30-11AM -74.004772  40.652073
# 624       THUR    8:30-10:30AM -73.850750  40.735740
# 625   WED/THUR  2-4PM/10AM-4PM -73.912934  40.668113
# 626   WED/THUR  2-4PM/10AM-4PM -73.912934  40.668113
# 627        FRI        10AM-1PM -74.222410  40.511820
#
#                                           FULL ADDRESS        BOROUGH  ...  \
# 0    138, Waverly Avenue, Clinton Hill, Brooklyn, K...       Brooklyn  ...
# 1    Bethanie Eglise Adventiste du 7eme Jour, 2059-...       Brooklyn  ...
# 2    521, Thomas S. Boyland Street, Brownsville, Br...       Brooklyn  ...
# 3    Ocean View Jewish Center, 3100, Brighton 4th S...       Brooklyn  ...
# 4    521, Thomas S. Boyland Street, Brownsville, Br...       Brooklyn  ...
# ..                                                 ...            ...  ...
# 623  443, 39th Street, Brooklyn, Kings County, City...       Brooklyn  ...
# 624  108-03, 62nd Drive, Forest Hills, Queens, Quee...         Queens  ...
# 625  521, Thomas S. Boyland Street, Brownsville, Br...       Brooklyn  ...
# 626  521, Thomas S. Boyland Street, Brownsville, Br...       Brooklyn  ...
# 627  6581, Hylan Boulevard, Staten Island, Richmond...  Staten Island  ...
#
#        sun  weeks_open  week_1  week_2  week_3  week_4  week_5    Time_Ranges  \
# 0     True         2,4   False    True   False    True   False  16:00 - 18:00
# 1    False   1,2,3,4,5    True    True    True    True    True  14:00 - 17:00
# 2    False   1,2,3,4,5    True    True    True    True    True   11:3 - 00:00
# 3    False   1,2,3,4,5    True    True    True    True    True  08:00 - 10:00
# 4    False   1,2,3,4,5    True    True    True    True    True  16:30 - 17:00
# ..     ...         ...     ...     ...     ...     ...     ...            ...
# 623  False   1,2,3,4,5    True    True    True    True    True  09:30 - 11:00
# 624  False   1,2,3,4,5    True    True    True    True    True  08:30 - 10:30
# 625  False   1,2,3,4,5    True    True    True    True    True  14:00 - 16:00
# 626  False   1,2,3,4,5    True    True    True    True    True  01:00 - 00:00
# 627  False   1,2,3,4,5    True    True    True    True    True  01:00 - 00:00
#
#     Start_Time  End_Time
# 0        16:00     18:00
# 1        14:00     17:00
# 2         11:3     00:00
# 3        08:00     10:00
# 4        16:30     17:00
# ..         ...       ...
# 623      09:30     11:00
# 624      08:30     10:30
# 625      14:00     16:00
# 626      01:00     00:00
# 627      01:00     00:00
#
# [628 rows x 27 columns]

# %%
test = df_expanded[['ID', 'HOURS', 'Time_Ranges', 'Start_Time', 'End_Time']]

# %%
test
# Out:
#         ID           HOURS    Time_Ranges Start_Time End_Time
# 0    80015           4-6PM  16:00 - 18:00      16:00    18:00
# 1    80026           2-5PM  14:00 - 17:00      14:00    17:00
# 2    80029  11:30AM-2:30PM   11:3 - 00:00       11:3    00:00
# 3    80065          8-10AM  08:00 - 10:00      08:00    10:00
# 4    80081        4:30-5PM  16:30 - 17:00      16:30    17:00
# ..     ...             ...            ...        ...      ...
# 623  87208       9:30-11AM  09:30 - 11:00      09:30    11:00
# 624  87233    8:30-10:30AM  08:30 - 10:30      08:30    10:30
# 625  87341  2-4PM/10AM-4PM  14:00 - 16:00      14:00    16:00
# 626  87341  2-4PM/10AM-4PM  01:00 - 00:00      01:00    00:00
# 627  87357        10AM-1PM  01:00 - 00:00      01:00    00:00
#
# [628 rows x 5 columns]

# %%
df_expanded.columns
# Out:
# Index(['ID', 'TYPE', 'PROGRAM', 'ORG PHONE', 'DAYS', 'HOURS', 'LONGITUDE',
#        'LATITUDE', 'FULL ADDRESS', 'BOROUGH', 'ZICODE', 'mon', 'tue', 'wed',
#        'thur', 'fri', 'sat', 'sun', 'weeks_open', 'week_1', 'week_2', 'week_3',
#        'week_4', 'week_5', 'Time_Ranges', 'Start_Time', 'End_Time'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['ID', 'TYPE', 'PROGRAM', 'ORG PHONE', 'DAYS', 'HOURS', 'LONGITUDE',
#        'LATITUDE', 'FULL ADDRESS', 'BOROUGH', 'ZICODE', 'mon', 'tue', 'wed',
#        'thur', 'fri', 'sat', 'sun', 'weeks_open', 'week_1', 'week_2', 'week_3',
#        'week_4', 'week_5', 'Time_Ranges'],
#       dtype='object')
