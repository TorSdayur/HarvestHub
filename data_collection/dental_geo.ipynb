# %%
import pandas as pd

df = pd.read_csv('csv/dental.csv')
df
# Out:
#                                            Clinic Name  \
# 0                        Sun River Health - Bay Street
# 1                  Community Health Center of Richmond
# 2        Metro Community Health Center - Staten Island
# 3      Community Health Center of Richmond Stapleton -
# 4          Staten Island University Hospital Northwell
# ..                                                 ...
# 108  Sunset Terrace Family Health Center, NYU Lango...
# 109                            Adapt Community Network
# 110             Joseph P. Addabbo Family Health Center
# 111       Wycoff Heights Medical Center, Department of
# 112      ODA Primary Health Care Network Dental Center
#
#                                  Address          City, State, Zip  \
# 0                              57 Bay St   Staten Island, NY 10301
# 1                  439 Port Richmond Ave   Staten Island, NY 10302
# 2                        2324 Forest Ave  Staten Island, NY 1030 3
# 3    St. George, 135 Canal St, Suite 200   Staten Island, NY 10304
# 4                        475 Seaview Ave   Staten Island, NY 10305
# ..                                   ...                       ...
# 108                          514 49th St                       NaN
# 109                     175 Lawrence Ave        Brooklyn, NY 11230
# 110                       120 Richard St                       NaN
# 111    Dental Medicine, 374 Stockholm St        Brooklyn, NY 11237
# 112                       58 Rutledge St                       NaN
#
#             Phone        Borough   id
# 0    855-681-8700  Staten Island    1
# 1    917-830-0838  Staten Island    2
# 2    718-447-0200  Staten Island    3
# 3    917-830-1950  Staten Island    4
# 4    718-226-9080  Staten Island    5
# ..            ...            ...  ...
# 108  718-431-2622       Brooklyn  109
# 109  718-436-7600       Brooklyn  110
# 110  718-945-7150       Brooklyn  111
# 111  718-963-7174       Brooklyn  112
# 112  718-260-4620       Brooklyn  113
#
# [113 rows x 6 columns]

# %%
from geopy.geocoders import Nominatim
from geopy.exc import GeocoderTimedOut
from tqdm import tqdm
import time
import re

# Initialize geocoder
geolocator = Nominatim(user_agent="my_app")



# Clean the address column
df['Full Address'] = df['Address'] + ', ' + df['City, State, Zip']
df['LONGITUDE'] = None
df['LATITUDE'] = None

# Function to get coordinates with retry logic
def get_coordinates(address, geolocator, retries=3):
    for _ in range(retries):
        try:
            location = geolocator.geocode(address, timeout=10)
            if location:
                return location.latitude, location.longitude
            else:
                return None, None
        except GeocoderTimedOut:
            time.sleep(1)
    return None, None

# Apply geocoding with progress bar
for idx, address in tqdm(enumerate(df['Full Address']), total=len(df), desc="Geocoding Addresses"):
    latitude, longitude = get_coordinates(address, geolocator)
    df.at[idx, 'LATITUDE'] = latitude
    df.at[idx, 'LONGITUDE'] = longitude

# Print the updated DataFrame
print(df[['Full Address', 'LATITUDE', 'LONGITUDE']])
# Out:
# Geocoding Addresses: 100%|██████████| 113/113 [01:20<00:00,  1.40it/s]
#                                           Full Address   LATITUDE  LONGITUDE
# 0                   57 Bay St, Staten Island, NY 10301  40.638722 -74.074764
# 1       439 Port Richmond Ave, Staten Island, NY 10302   40.63138 -74.138315
# 2            2324 Forest Ave, Staten Island, NY 1030 3       None       None
# 3    St. George, 135 Canal St, Suite 200, Staten Is...       None       None
# 4             475 Seaview Ave, Staten Island, NY 10305  40.585438 -74.084764
# ..                                                 ...        ...        ...
# 108                                                NaN  46.314475  11.048029
# 109               175 Lawrence Ave, Brooklyn, NY 11230  40.630978 -73.973463
# 110                                                NaN  46.314475  11.048029
# 111  Dental Medicine, 374 Stockholm St, Brooklyn, N...       None       None
# 112                                                NaN  46.314475  11.048029
#
# [113 rows x 3 columns]

# %%
nan_latitude_count = df['LATITUDE'].isna().sum()
nan_longitude_count = df['LONGITUDE'].isna().sum()

nan_latitude_count, nan_longitude_count
# Out:
# (55, 55)

# %%
df_nan_latitude = df[df['LATITUDE'].isna()]
df_nan_latitude
# Out:
#                                            Clinic Name  \
# 2        Metro Community Health Center - Staten Island
# 3      Community Health Center of Richmond Stapleton -
# 5              161st Street Dental Clinic (Montefiore)
# 7                            Sun River Health - Inwood
# 8         Morrisania Diagnostic and Treatment Center *
# 13     Walton Family Health Practice Dental Department
# 16   BronxCare Dr. Martin Luther King, Jr. Health C...
# 23      Children’s Aid Society - Bronx Health Services
# 24                 Blondell Dental Clinic (Montefiore)
# 25               Jarrett Pediatric Clinic (Montefiore)
# 26       Jacobi Medical Center Department of Dentistry
# 27            5500 Broadway Dental Clinic (Montefiore)
# 30               Centennial Dental Clinic (Montefiore)
# 31          North Central Bronx Hospital Dental Clinic
# 32                   Schiff Dental Clinic (Montefiore)
# 36                       Lower East Side Health Center
# 37                                    Ryan Health NENA
# 38            New York University College of Dentistry
# 39    NYU Dentistry Oral Health Center for People with
# 42             Charles B. Wang Community Health Center
# 43   Bellevue Department of Oral and Maxillofacial ...
# 44       Bellevue Department of Oral and Maxillofacial
# 45   New York Presbyterian/Weill Cornell Dental Pra...
# 46   New York Presbyterian/Weill Cornell Dental Pra...
# 47              Mount Sinai St. Luke’s - Dental Clinic
# 48                        Ryan Health West 97th Street
# 50                                Harlem Health Center
# 51                         Renaissance Sydenham Center
# 52                                   Ryan Health Adair
# 53                 Metropolitan Hospital Dental Center
# 54                          Heritage Healthcare Center
# 55      Columbia University College of Dental Medicine
# 56      Columbia University College of Dental Medicine
# 57                  Boriken Neighborhood Health Center
# 58                      Family Health Center of Harlem
# 61             Harlem Hospital Department of Dentistry
# 65    New York -Presbyterian Queens - Dental Emergency
# 66   New York Presbyterian  Queens - Center for Dental
# 68                      Apicha Community Health Center
# 70     MediSys Health Network - Ozone Park (Clocktower
# 71            MediSys - Jamaica Hospital Dental Clinic
# 72         Firehouse Health Center (Damian Family Care
# 73                         Health and Hospitals Queens
# 74                 MediSys Health Network - St. Albans
# 79               Joseph P Addabbo Family Health Center
# 80               Joseph P Addabbo Family Health Center
# 81        The Brooklyn Hospital Center - Dentistry and
# 85                     Cumberland Gotham Health Center
# 86    Whitman Ingersoll Farragut Health Center of BPMC
# 91     Brownsville Multi -Service Family Health Center
# 97   Interfaith Medical Center - Smile Brooklyn Dental
# 98         NYU Langone Family Health Center Park Slope
# 99           NY Presbyterian Methodist Brooklyn Dental
# 104                          Maimonides Medical Center
# 111       Wycoff Heights Medical Center, Department of
#
#                                                Address  \
# 2                                      2324 Forest Ave
# 3                  St. George, 135 Canal St, Suite 200
# 5                       305 East 161st St, Lower Level
# 7                                  1543- 45 Inwood Ave
# 8                          1225 Gerard Ave, 3rd  Floor
# 13   (The Institute for Family Health), 1894 Walton...
# 16                        1265 Franklin Ave, 3rd Floor
# 23                        910 East 172nd St, 3rd Floor
# 24   1575 Blondell Ave, Suite 150,, DENT AL CLINICS...
# 25          1516 Jarrett Place, Lower Level, Suite 100
# 26           1400 Pelham Pkwy South, Bldg 1, 3rd Floor
# 27                            5500 Broadway, Suite 102
# 30                      3332 Rochambeau Ave, 2nd Floor
# 31                           3424 Kossuth Ave, Unit 2A
# 32                         3444 Kossuth Ave, 1st Floor
# 36   (Community Healthcare Network), 225 East Houst...
# 37                                    279 E ast 3rd St
# 38                                   345 E ast 24th St
# 39           Disabilities, 345 East 24th St, 8th Floor
# 42                            125 Walker St, 2nd Floor
# 43         (adult), 462 1st Ave, H building, 5th Floor
# 44   Surgery (pediatric), 462 1st Ave, Ambulatory, ...
# 45               (adult), 525 East 68th St, 21st Floor
# 46   (pediatric), 505 East 70th St, Helmsley Tower,...
# 47    1468 Madison Ave, Annenberg Building, Suite A202
# 48                                   110 W est 97th St
# 50   (Community Healthcare Network), 81 W est 115th St
# 51                                  264 W est 118th St
# 52   565 Manhattan Ave, DENT AL CLINICS – MANHATTAN...
# 53                        1901 1st Ave, 2nd Floor, 2D3
# 54                       1727 Amsterdam Ave, 4th Floor
# 55                          (adult), 622 West 168th St
# 56                      (pediatric), 722 West 168th St
# 57                             2265 3rd Ave, 4th Floor
# 58                       1824 Madison Ave, Lower Level
# 61             15 West 136th St, Building K, Mezzanine
# 65                           Department, 56-45 Main St
# 66       and Oral Medicine, 174-11 Horace Harding Expy
# 68                          82-11 37th  Ave, 4th Floor
# 70                          Plaza), 91-20 Atlantic Ave
# 71                       134-20 Jamaica Ave, 3rd Floor
# 72                             Center), 89-56 162nd St
# 73      82-68 164th St, Pavilion Building -  2nd Floor
# 74                                 111-20 Merrick Blvd
# 79   1288 Central Ave, DENT AL CLINICS – QUEENS,, A...
# 80                               6200 Beach Channel Dr
# 81   Oral/Maxillofacial Surgery Ce nter, 155 Ashlan...
# 85                   100 North Portland Ave, 3rd Floor
# 86                                     297 Myr tle Ave
# 91                  Ashford, 650 Ashford St, 2nd Floor
# 97                           Clinic, 1545 Atlantic Ave
# 98   220 13th St,,, August 202 3, *This clinic is u...
# 99   Services, 506 6th St, Kirkwood Pavilion, 1st F...
# 104               4802 10th Ave, Admin Bldg, 2nd Floor
# 111                  Dental Medicine, 374 Stockholm St
#
#                 City, State, Zip         Phone        Borough   id  \
# 2       Staten Island, NY 1030 3  718-447-0200  Staten Island    3
# 3        Staten Island, NY 10304  917-830-1950  Staten Island    4
# 5                Bronx, NY 10451  718-579-2535          Bronx    6
# 7                Bronx, NY 10452  855-681-8700          Bronx    8
# 8                Bronx, NY 10452  718-960-2911          Bronx    9
# 13               Bronx, NY 10453  718-583-2700          Bronx   14
# 79   1288 Central Ave, DENT AL CLINICS – QUEENS,, A...      None     None
# 80           6200 Beach Channel Dr, Arverne, NY 1169 2      None     None
# 81   Oral/Maxillofacial Surgery Ce nter, 155 Ashlan...      None     None
# 85   100 North Portland Ave, 3rd Floor, Brooklyn, N...      None     None
# 86                 297 Myr tle Ave, Brooklyn, NY 11205      None     None
# 91   Ashford, 650 Ashford St, 2nd Floor, Brooklyn, ...      None     None
# 97       Clinic, 1545 Atlantic Ave, Brooklyn, NY 11213      None     None
# 98   220 13th St,,, August 202 3, *This clinic is u...      None     None
# 99   Services, 506 6th St, Kirkwood Pavilion, 1st F...      None     None
# 104  4802 10th Ave, Admin Bldg, 2nd Floor, Brooklyn...      None     None
# 111  Dental Medicine, 374 Stockholm St, Brooklyn, N...      None     None

# %%
# Function to remove content inside parentheses
def remove_parentheses(text):
    return re.sub(r'\([^)]*\)', '', text).strip()

# Apply the function to remove parentheses from the 'Full Address' column
df_nan_latitude['Cleaned Address'] = df_nan_latitude['Address'].apply(remove_parentheses)

# Display the cleaned addresses
df_nan_latitude[['Address', 'Cleaned Address']]
# Out:
# C:\Users\dougl\AppData\Local\Temp\ipykernel_23728\1061840586.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nan_latitude['Cleaned Address'] = df_nan_latitude['Address'].apply(remove_parentheses)
#                                                Address  \
# 2                                      2324 Forest Ave
# 3                  St. George, 135 Canal St, Suite 200
# 5                       305 East 161st St, Lower Level
# 7                                  1543- 45 Inwood Ave
# 8                          1225 Gerard Ave, 3rd  Floor
# 13   (The Institute for Family Health), 1894 Walton...
# 16                        1265 Franklin Ave, 3rd Floor
# 23                        910 East 172nd St, 3rd Floor
# 24   1575 Blondell Ave, Suite 150,, DENT AL CLINICS...
# 25          1516 Jarrett Place, Lower Level, Suite 100
# 26           1400 Pelham Pkwy South, Bldg 1, 3rd Floor
# 27                            5500 Broadway, Suite 102
# 30                      3332 Rochambeau Ave, 2nd Floor
# 31                           3424 Kossuth Ave, Unit 2A
# 32                         3444 Kossuth Ave, 1st Floor
# 36   (Community Healthcare Network), 225 East Houst...
# 37                                    279 E ast 3rd St
# 38                                   345 E ast 24th St
# 39           Disabilities, 345 East 24th St, 8th Floor
# 42                            125 Walker St, 2nd Floor
# 43         (adult), 462 1st Ave, H building, 5th Floor
# 44   Surgery (pediatric), 462 1st Ave, Ambulatory, ...
# 45               (adult), 525 East 68th St, 21st Floor
# 46   (pediatric), 505 East 70th St, Helmsley Tower,...
# 47    1468 Madison Ave, Annenberg Building, Suite A202
# 48                                   110 W est 97th St
# 50   (Community Healthcare Network), 81 W est 115th St
# 51                                  264 W est 118th St
# 52   565 Manhattan Ave, DENT AL CLINICS – MANHATTAN...
# 53                        1901 1st Ave, 2nd Floor, 2D3
# 54                       1727 Amsterdam Ave, 4th Floor
# 55                          (adult), 622 West 168th St
# 56                      (pediatric), 722 West 168th St
# 57                             2265 3rd Ave, 4th Floor
# 58                       1824 Madison Ave, Lower Level
# 61             15 West 136th St, Building K, Mezzanine
# 65                           Department, 56-45 Main St
# 80                               6200 Beach Channel Dr
# 81   Oral/Maxillofacial Surgery Ce nter, 155 Ashlan...
# 85                   100 North Portland Ave, 3rd Floor
# 86                                     297 Myr tle Ave
# 91                  Ashford, 650 Ashford St, 2nd Floor
# 97                           Clinic, 1545 Atlantic Ave
# 98   220 13th St,,, August 202 3, *This clinic is u...
# 99   Services, 506 6th St, Kirkwood Pavilion, 1st F...
# 104               4802 10th Ave, Admin Bldg, 2nd Floor
# 111                  Dental Medicine, 374 Stockholm St

# %%
# Function to remove leading commas from the Cleaned Address column
def remove_leading_comma(text):
    return text.lstrip(',')

# Apply the function to remove leading commas
df_nan_latitude['Cleaned Address'] = df_nan_latitude['Cleaned Address'].apply(remove_leading_comma)

# Display the first few rows to confirm the changes
df_nan_latitude[['Address', 'Cleaned Address']]
# Out:
# C:\Users\dougl\AppData\Local\Temp\ipykernel_23728\663507303.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nan_latitude['Cleaned Address'] = df_nan_latitude['Cleaned Address'].apply(remove_leading_comma)
#                                                Address  \
# 2                                      2324 Forest Ave
# 3                  St. George, 135 Canal St, Suite 200
# 5                       305 East 161st St, Lower Level
# 7                                  1543- 45 Inwood Ave
# 8                          1225 Gerard Ave, 3rd  Floor
# 13   (The Institute for Family Health), 1894 Walton...
# 16                        1265 Franklin Ave, 3rd Floor
# 23                        910 East 172nd St, 3rd Floor
# 24   1575 Blondell Ave, Suite 150,, DENT AL CLINICS...
# 25          1516 Jarrett Place, Lower Level, Suite 100
# 26           1400 Pelham Pkwy South, Bldg 1, 3rd Floor
# 27                            5500 Broadway, Suite 102
# 30                      3332 Rochambeau Ave, 2nd Floor
# 31                           3424 Kossuth Ave, Unit 2A
# 32                         3444 Kossuth Ave, 1st Floor
# 36   (Community Healthcare Network), 225 East Houst...
# 37                                    279 E ast 3rd St
# 38                                   345 E ast 24th St
# 39           Disabilities, 345 East 24th St, 8th Floor
# 42                            125 Walker St, 2nd Floor
# 43         (adult), 462 1st Ave, H building, 5th Floor
# 44   Surgery (pediatric), 462 1st Ave, Ambulatory, ...
# 45               (adult), 525 East 68th St, 21st Floor
# 46   (pediatric), 505 East 70th St, Helmsley Tower,...
# 47    1468 Madison Ave, Annenberg Building, Suite A202
# 48                                   110 W est 97th St
# 50   (Community Healthcare Network), 81 W est 115th St
# 51                                  264 W est 118th St
# 52   565 Manhattan Ave, DENT AL CLINICS – MANHATTAN...
# 53                        1901 1st Ave, 2nd Floor, 2D3
# 54                       1727 Amsterdam Ave, 4th Floor
# 55                          (adult), 622 West 168th St
# 56                      (pediatric), 722 West 168th St
# 57                             2265 3rd Ave, 4th Floor
# 58                       1824 Madison Ave, Lower Level
# 61             15 West 136th St, Building K, Mezzanine
# 65                           Department, 56-45 Main St
# 66       and Oral Medicine, 174-11 Horace Harding Expy
# 68                          82-11 37th  Ave, 4th Floor
# 70                          Plaza), 91-20 Atlantic Ave
# 71                       134-20 Jamaica Ave, 3rd Floor
# 97                           Clinic, 1545 Atlantic Ave
# 98   220 13th St,,, August 202 3, *This clinic is u...
# 99   Services, 506 6th St, Kirkwood Pavilion, 1st F...
# 104               4802 10th Ave, Admin Bldg, 2nd Floor
# 111                  Dental Medicine, 374 Stockholm St

# %%
from tqdm import tqdm

for idx, address in tqdm(enumerate(df_nan_latitude['Cleaned Address']), total=len(df_nan_latitude), desc="Geocoding Addresses"):
    latitude, longitude = get_coordinates(address, geolocator)
    df_nan_latitude.at[idx, 'LATITUDE'] = latitude
    df_nan_latitude.at[idx, 'LONGITUDE'] = longitude

# Print the updated DataFrame with the relevant columns
print(df_nan_latitude[['Cleaned Address', 'LATITUDE', 'LONGITUDE']])
# Out:
# Geocoding Addresses: 100%|██████████| 79/79 [01:03<00:00,  1.25it/s]
#                         Cleaned Address   LATITUDE  LONGITUDE
# 2                       2324 Forest Ave       None       None
# 3   St. George, 135 Canal St, Suite 200  40.860465 -73.038858
# 5        305 East 161st St, Lower Level   51.95588   1.326434
# 7                   1543- 45 Inwood Ave       None       None
# 8           1225 Gerard Ave, 3rd  Floor       None       None
# ..                                  ...        ...        ...
# 69                                  NaN  46.314475  11.048029
# 75                                  NaN  46.314475  11.048029
# 76                                  NaN  46.314475  11.048029
# 77                                  NaN  46.314475  11.048029
# 78                                  NaN  46.314475  11.048029
#
# [90 rows x 3 columns]

# %%
df_nan_latitude
# Out:
#                                         Clinic Name  \
# 2     Metro Community Health Center - Staten Island
# 3   Community Health Center of Richmond Stapleton -
# 5           161st Street Dental Clinic (Montefiore)
# 7                         Sun River Health - Inwood
# 8      Morrisania Diagnostic and Treatment Center *
# ..                                              ...
# 69                                              NaN
# 75                                              NaN
# 76                                              NaN
# 77                                              NaN
# 78                                              NaN
#
#                                 Address          City, State, Zip  \
# 2                       2324 Forest Ave  Staten Island, NY 1030 3
# 3   St. George, 135 Canal St, Suite 200   Staten Island, NY 10304
# 5        305 East 161st St, Lower Level           Bronx, NY 10451
# 7                   1543- 45 Inwood Ave           Bronx, NY 10452
# 8           1225 Gerard Ave, 3rd  Floor           Bronx, NY 10452
# ..                                  ...                       ...
# 69                                  NaN                       NaN
# 75                                  NaN                       NaN
# 76                                  NaN                       NaN
# 77                                  NaN                       NaN
# 78                                  NaN                       NaN
#
#            Phone        Borough   id  \
# 2   718-447-0200  Staten Island  3.0
# 3   917-830-1950  Staten Island  4.0
# 5   718-579-2535          Bronx  6.0
# 7   855-681-8700          Bronx  8.0
# 8   718-960-2911          Bronx  9.0
# ..           ...            ...  ...
# 69           NaN            NaN  NaN
# 75           NaN            NaN  NaN
# 76           NaN            NaN  NaN
# 77           NaN            NaN  NaN
# 78           NaN            NaN  NaN
#
#                                          Full Address  LONGITUDE   LATITUDE  \
# 2           2324 Forest Ave, Staten Island, NY 1030 3       None       None
# 3   St. George, 135 Canal St, Suite 200, Staten Is... -73.038858  40.860465
# 5     305 East 161st St, Lower Level, Bronx, NY 10451   1.326434   51.95588
# 7                1543- 45 Inwood Ave, Bronx, NY 10452       None       None
# 8        1225 Gerard Ave, 3rd  Floor, Bronx, NY 10452       None       None
# ..                                                ...        ...        ...
# 69                                                NaN  11.048029  46.314475
# 75                                                NaN  11.048029  46.314475
# 76                                                NaN  11.048029  46.314475
# 77                                                NaN  11.048029  46.314475
# 78                                                NaN  11.048029  46.314475
#
#                         Cleaned Address
# 2                       2324 Forest Ave
# 3   St. George, 135 Canal St, Suite 200
# 5        305 East 161st St, Lower Level
# 7                   1543- 45 Inwood Ave
# 8           1225 Gerard Ave, 3rd  Floor
# ..                                  ...
# 69                                  NaN
# 75                                  NaN
# 76                                  NaN
# 77                                  NaN
# 78                                  NaN
#
# [90 rows x 10 columns]

# %%
df_nan_latitude.dropna(subset=['Clinic Name'], inplace=True)

# %%
df_nan_latitude.columns
# Out:
# Index(['Clinic Name', 'City, State, Zip', 'Phone', 'Borough', 'id',
#        'Full Address', 'LONGITUDE', 'LATITUDE', 'Address'],
#       dtype='object')

# %%
df_nan_latitude.drop(columns=['Address'], inplace=True)

# Rename 'Cleaned Address' to 'Address'
df_nan_latitude.rename(columns={'Cleaned Address': 'Address'}, inplace=True)

# %%
df.columns
# Out:
# Index(['Clinic Name', 'Address', 'City, State, Zip', 'Phone', 'Borough', 'id',
#        'Full Address', 'LONGITUDE', 'LATITUDE'],
#       dtype='object')

# %%
# Step 1: Create a subset of df without NaN values in LATITUDE and LONGITUDE
df_no_nan = df.dropna(subset=['LATITUDE', 'LONGITUDE'])

# Step 2: Append df_nan_latitude to this subset
df_combined = pd.concat([df_no_nan, df_nan_latitude], ignore_index=True)

# Display the first few rows of the combined DataFrame to confirm
df_combined.head()
# Out:
#                                        Clinic Name  \
# 0                    Sun River Health - Bay Street
# 1              Community Health Center of Richmond
# 2  Community Health Center of Richmond Stapleton -
# 3      Staten Island University Hospital Northwell
# 4          161st Street Dental Clinic (Montefiore)
#
#                                Address         City, State, Zip         Phone  \
# 0                            57 Bay St  Staten Island, NY 10301  855-681-8700
# 1                439 Port Richmond Ave  Staten Island, NY 10302  917-830-0838
# 2  St. George, 135 Canal St, Suite 200  Staten Island, NY 10304  917-830-1950
# 3                      475 Seaview Ave  Staten Island, NY 10305  718-226-9080
# 4       305 East 161st St, Lower Level          Bronx, NY 10451  718-579-2535
#
#          Borough   id                                       Full Address  \
# 0  Staten Island  1.0                 57 Bay St, Staten Island, NY 10301
# 1  Staten Island  2.0     439 Port Richmond Ave, Staten Island, NY 10302
# 2  Staten Island  4.0  St. George, 135 Canal St, Suite 200, Staten Is...
# 3  Staten Island  5.0           475 Seaview Ave, Staten Island, NY 10305
# 4          Bronx  6.0    305 East 161st St, Lower Level, Bronx, NY 10451
#
#    LONGITUDE   LATITUDE
# 0 -74.074764  40.638722
# 1 -74.138315   40.63138
# 2 -73.038858  40.860465
# 3 -74.084764  40.585438
# 4   1.326434   51.95588

# %%
df_combined
# Out:
#                                            Clinic Name  \
# 0                        Sun River Health - Bay Street
# 1                  Community Health Center of Richmond
# 2      Community Health Center of Richmond Stapleton -
# 3          Staten Island University Hospital Northwell
# 4              161st Street Dental Clinic (Montefiore)
# ..                                                 ...
# 132  Interfaith Medical Center - Smile Brooklyn Dental
# 133        NYU Langone Family Health Center Park Slope
# 134          NY Presbyterian Methodist Brooklyn Dental
# 135                          Maimonides Medical Center
# 136       Wycoff Heights Medical Center, Department of
#
#                                                Address  \
# 0                                            57 Bay St
# 1                                439 Port Richmond Ave
# 2                  St. George, 135 Canal St, Suite 200
# 3                                      475 Seaview Ave
# 4                       305 East 161st St, Lower Level
# ..                                                 ...
# 132                          Clinic, 1545 Atlantic Ave
# 133  220 13th St,,, August 202 3, *This clinic is u...
# 134  Services, 506 6th St, Kirkwood Pavilion, 1st F...
# 135               4802 10th Ave, Admin Bldg, 2nd Floor
# 136                  Dental Medicine, 374 Stockholm St
#
#             City, State, Zip         Phone        Borough     id  \
# 0    Staten Island, NY 10301  855-681-8700  Staten Island    1.0
# 1    Staten Island, NY 10302  917-830-0838  Staten Island    2.0
# 2    Staten Island, NY 10304  917-830-1950  Staten Island    4.0
# 3    Staten Island, NY 10305  718-226-9080  Staten Island    5.0
# 4            Bronx, NY 10451  718-579-2535          Bronx    6.0
# ..                       ...           ...            ...    ...
# 132       Brooklyn, NY 11213  718-613-7140       Brooklyn   98.0
# 133       Brooklyn, NY 11215  718-832-5980       Brooklyn   99.0
# 134       Brooklyn, NY 11215  718-780-5410       Brooklyn  100.0
# 135       Brooklyn, NY 11219  718-283-2084       Brooklyn  105.0
# 136       Brooklyn, NY 11237  718-963-7174       Brooklyn  112.0
#
#                                           Full Address  LONGITUDE   LATITUDE
# 0                   57 Bay St, Staten Island, NY 10301 -74.074764  40.638722
# 1       439 Port Richmond Ave, Staten Island, NY 10302 -74.138315   40.63138
# 2    St. George, 135 Canal St, Suite 200, Staten Is... -73.038858  40.860465
# 3             475 Seaview Ave, Staten Island, NY 10305 -74.084764  40.585438
# 4      305 East 161st St, Lower Level, Bronx, NY 10451   1.326434   51.95588
# ..                                                 ...        ...        ...
# 132      Clinic, 1545 Atlantic Ave, Brooklyn, NY 11213       None       None
# 133  220 13th St,,, August 202 3, *This clinic is u...       None       None
# 134  Services, 506 6th St, Kirkwood Pavilion, 1st F...       None       None
# 135  4802 10th Ave, Admin Bldg, 2nd Floor, Brooklyn...       None       None
# 136  Dental Medicine, 374 Stockholm St, Brooklyn, N...       None       None
#
# [137 rows x 9 columns]

# %%
# Check the number of NaN values in LATITUDE and LONGITUDE in the combined DataFrame
nan_count_latitude = df_combined['LATITUDE'].isna().sum()
nan_count_longitude = df_combined['LONGITUDE'].isna().sum()

print(f"NaN values in LATITUDE: {nan_count_latitude}")
print(f"NaN values in LONGITUDE: {nan_count_longitude}")
# Out:
# NaN values in LATITUDE: 31
# NaN values in LONGITUDE: 31

# %%
df_combined.to_csv('dental.csv', index=False)
